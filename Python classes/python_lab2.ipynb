# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1. NumPy: Numerical Arrays

# %% [markdown]
# - Q1.1: Create a 1D NumPy array with 10 equally spaced values between 0 and 100. Then, reshape this array into a 2x5 matrix.
# array_1d = np.linspace(0, 100, 10)
#     - Expected Output: A $2 \times 5$ array of floats.

# %%
#write your solution here

# %% [markdown]
# - Q1.2: Create a 3x3 array of random integers between 1 and 50. Write code to:
#
# - Find the mean of the entire array.
#
# - Extract the entire second column of the array.
#
#     - Expected Output: The mean value and a 1D array of the second column.

# %%
#write your solution here

# %% [markdown]
# ### 2. Pandas: DataFrames

# %%
# Q2.1: Create a Pandas DataFrame from the following dictionary:
data = {
    'Product': ['Laptop', 'Mouse', 'Monitor', 'Keyboard'],
    'Price': [1200, 25, 300, 75],
    'Stock': [10, 50, 0, 22]

}

# %% [markdown]
# Display the first 2 rows

# %%
# write your solution here

# %% [markdown]
# Filter the DataFrame to show only products that are out of stock (Stock == 0).

# %%
# write your solution here

# %% [markdown]
# - Q2.2: Using the same DataFrame:
#    - Add a new column called Total_Value which is calculated by multiplying Price and Stock.
#
#    - Calculate the total sum of the Total_Value column.

# %%
# write your solution here

# %% [markdown]
# ### 3. Data Cleaning & Analysis

# %%
# Q3.1: Given a DataFrame with missing values:
import pandas as pd
import numpy as np
df = pd.DataFrame({'A': [1, 2, np.nan, 4], 'B': [5, np.nan, 7, 8]})

# %% [markdown]
# Fill the missing values (NaN) with the mean of their respective columns.

# %%
# write your solution here

# %% [markdown]
# Drop the rows where the value in column 'A' is greater than 2.

# %%
# write your solution here
